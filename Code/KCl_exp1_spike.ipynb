# %%
#imports
import os
from pathlib import Path 
import allego_file_reader as afr
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt
from xdat_loader import list_xdat_sources, print_all_xdat_names, load_xdat_by_index

# %%
# this is needed to read in the files
target_dir = "/Users/ebennett/Library/CloudStorage/Dropbox-EMI/Evelyn Bennett/project_electrodes/electrode_data/electrode-analysis/Data/20260115_CRC_KCl" # data directory

# %%
all_xdat_sources = list_xdat_sources(target_dir)
print_all_xdat_names(target_dir)

# %%
# i made a  fxn to do this so its way quicker
# since files names and indexes are incosistent i thought it was safer to 
# feed the index manually
data_media_pre = load_xdat_by_index(target_dir, 1)  # media pre kcl
data_media_post = load_xdat_by_index(target_dir, 4)  # media post kcl
data_crc_dose1 = load_xdat_by_index(target_dir, 2)  # crc post kcl dose 1
data_crc_dose2 = load_xdat_by_index(target_dir, 5)  # crc post kcl dose 2
data_crc_pre = load_xdat_by_index(target_dir, 0)  # crc pre kcl
data_crc_veh = load_xdat_by_index(target_dir, 3)  # crc vehicle control

# %%
# id can be adjusted

id = 5
start = int(0)
end   = int(5e6)

# %%
#segment 1 times
times_mediaPre_seg1  = data_media_pre["segment_1"]["time_samples"][start:end]
times_mediaPost_seg1 = data_media_post["segment_1"]["time_samples"][start:end]
times_crcCtrl_seg1   = data_crc_veh["segment_1"]["time_samples"][start:end]
times_crcPre_seg1    = data_crc_pre["segment_1"]["time_samples"][start:end]
times_crcpost1_seg1  = data_crc_dose1["segment_1"]["time_samples"][start:end]
times_crcpost2_seg1  = data_crc_dose2["segment_1"]["time_samples"][start:end]

#segment 2 times
times_mediaPre_seg2  = data_media_pre["segment_2"]["time_samples"][start:end]
times_mediaPost_seg2 = data_media_post["segment_2"]["time_samples"][start:end]
times_crcCtrl_seg2   = data_crc_veh["segment_2"]["time_samples"][start:end]
times_crcPre_seg2    = data_crc_pre["segment_2"]["time_samples"][start:end]
times_crcpost1_seg2  = data_crc_dose1["segment_2"]["time_samples"][start:end]
times_crcpost2_seg2  = data_crc_dose2["segment_2"]["time_samples"][start:end]

#segment 1 signals
mediaPre_seg1   = data_media_pre["segment_1"]["signals"][id][start:end]
mediaPost_seg1  = data_media_post["segment_1"]["signals"][id][start:end]
crcCtrl_seg1    = data_crc_veh["segment_1"]["signals"][id][start:end]
crcpre_seg1     = data_crc_pre["segment_1"]["signals"][id][start:end]
crcpost1_seg1   = data_crc_dose1["segment_1"]["signals"][id][start:end]
crcpost2_seg1   = data_crc_dose2["segment_1"]["signals"][id][start:end]

#segment 2 signals
mediaPre_seg2   = data_media_pre["segment_2"]["signals"][id][start:end]
mediaPost_seg2  = data_media_post["segment_2"]["signals"][id][start:end]
crcCtrl_seg2    = data_crc_veh["segment_2"]["signals"][id][start:end]
crcpre_seg2     = data_crc_pre["segment_2"]["signals"][id][start:end]
crcpost1_seg2   = data_crc_dose1["segment_2"]["signals"][id][start:end]
crcpost2_seg2   = data_crc_dose2["segment_2"]["signals"][id][start:end]

# %%
plt.figure(figsize=(8,6))
plt.plot(times_crcpost2_seg1, crcpost2_seg1, alpha=0.7, label='Potential Spike', color='blue')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (µV)')
plt.xlim(22.7, 23.5)
plt.ylim(-3500, 3500)
plt.title('Electrode ID 5 CRC Post-KCl Dose 2 (Spike Segment)')
plt.legend()

# %%
plt.figure(figsize=(8,6))
plt.plot(times_crcpost1_seg1, crcpost1_seg1, alpha=0.7, label='Potential Spike', color='orange')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (µV)')
plt.xlim(36.1, 36.9)
plt.ylim(-3500, 3500)
plt.title('Electrode ID 5 CRC Post-KCl Dose 1 (Spike Segment)')
plt.legend()

# %%
import numpy as np

t0 = 25.0  # seconds
idx_25 = np.argmin(np.abs(times_crcCtrl_seg1 - t0))
print(idx_25)

times_crcCtrl_seg1_aligned = (
    times_crcCtrl_seg1 - times_crcCtrl_seg1[idx_25]
)

crcCtrl_seg1_aligned = (
    crcCtrl_seg1 - crcCtrl_seg1[idx_25]
)

times_crcCtrl_seg1_aligned[idx_25] == 0



#crcCtrl_seg1_adjust    = data_crc_veh["segment_1"]["signals"][id][int(0.31e6):end]
#times_crcCtrl_seg1_adjust   = data_crc_veh["segment_1"]["time_samples"][start:int(4.69e6)]

# %%
# plot media pre, media post, crc pre dose 1, crc vehicle control for comparison

plt.figure(figsize=(24, 12))
#CRC pre all treatments
plt.subplot(231)
plt.plot(times_crcPre_seg1, crcpre_seg1, alpha=0.7, label='CRC Pre-Dosing', color='firebrick')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (µV)')
plt.title('Electrode ID 5 CRC Pre-KCl Dosing')
plt.xlim(36.1, 36.9)
plt.ylim(-3500, 3500)
plt.legend()

# crc vehicle control
plt.subplot(232)
plt.plot(times_crcCtrl_seg1_aligned, crcCtrl_seg1_aligned, alpha=0.7, label='CRC Vehicle Control (PBS)', color='yellowgreen')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (µV)')
plt.xlim(36.1, 36.9)
plt.ylim(-3500, 3500)
plt.title('Electrode ID 5 CRC Vehicle Control Dosing (PBS)')
plt.legend()

#mcrc post dose 1
plt.subplot(233)
plt.plot(times_crcpost1_seg1, crcpost1_seg1, alpha=0.7, label='Potential Spike', color='orange')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (µV)')
plt.xlim(36.1, 36.9)
plt.ylim(-3500, 3500)
plt.title('Electrode ID 5 CRC Post-KCl Dose 1 (Spike Segment)')
plt.legend()


# media pre kcl
plt.subplot(234)
plt.plot(times_mediaPre_seg1, mediaPre_seg1, alpha=0.7, label='Media Pre-KCl', color='pink')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (µV)')
plt.xlim(36.1, 36.9)
plt.ylim(-3500, 3500)
plt.title('Electrode ID 5 Media Pre-KCl Dosing')
plt.legend()

# media post kcl
plt.subplot(235)
plt.plot(times_mediaPost_seg1, mediaPost_seg1, alpha=0.7, label='Media Post-KCl', color='deeppink')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (µV)')
plt.xlim(36.1, 36.9)
plt.ylim(-3500, 3500)
plt.title('Electrode ID 5 Media Post-KCl Dosing')
plt.legend() 

# all plots
plt.subplot(236)
plt.plot(times_crcPre_seg1, crcpre_seg1, alpha=0.7, label='CRC Pre-Dosing', color='firebrick')
plt.plot(times_crcCtrl_seg1_aligned, crcCtrl_seg1_aligned, alpha=0.7, label='CRC Vehicle Control (PBS)', color='yellowgreen')
plt.plot(times_crcpost1_seg1, crcpost1_seg1, alpha=0.7, label='Potential Spike', color='orange')
plt.plot(times_mediaPre_seg1, mediaPre_seg1, alpha=0.7, label='Media Pre-KCl', color='pink')
plt.plot(times_mediaPost_seg1, mediaPost_seg1, alpha=0.7, label='Media Post-KCl', color='deeppink')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (µV)')
plt.title('All Segments')
plt.xlim(36.1, 36.9)
plt.ylim(-3500, 3500)
plt.legend()

# %%
# plot media pre, media post, crc pre dose 1, crc vehicle control for comparison

plt.figure(figsize=(24, 12))
#CRC pre all treatments
plt.subplot(231)
plt.plot(times_crcPre_seg1, crcpre_seg1, alpha=0.7, label='CRC Pre-Dosing', color='firebrick')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (µV)')
plt.title('Electrode ID 5 CRC Pre-KCl Dosing')
plt.xlim(22.7, 23.5)
plt.ylim(-3500, 3500)
plt.legend()

# crc vehicle control
plt.subplot(232)
plt.plot(times_crcCtrl_seg1_aligned, crcCtrl_seg1_aligned, alpha=0.7, label='CRC Vehicle Control (PBS)', color='yellowgreen')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (µV)')
plt.xlim(22.7, 23.5)
plt.ylim(-3500, 3500)
plt.title('Electrode ID 5 CRC Vehicle Control Dosing (PBS)')
plt.legend()

#mcrc post dose 1
plt.subplot(233)
plt.plot(times_crcpost2_seg1, crcpost2_seg1, alpha=0.7, label='Potential Spike', color='blue')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (µV)')
plt.xlim(22.7, 23.5)
plt.ylim(-3500, 3500)
plt.title('Electrode ID 5 CRC Post-KCl Dose 1 (Spike Segment)')
plt.legend()


# media pre kcl
plt.subplot(234)
plt.plot(times_mediaPre_seg1, mediaPre_seg1, alpha=0.7, label='Media Pre-KCl', color='pink')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (µV)')
plt.xlim(22.7, 23.5)
plt.ylim(-3500, 3500)
plt.title('Electrode ID 5 Media Pre-KCl Dosing')
plt.legend()

# media post kcl
plt.subplot(235)
plt.plot(times_mediaPost_seg1, mediaPost_seg1, alpha=0.7, label='Media Post-KCl', color='deeppink')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (µV)')
plt.xlim(22.7, 23.5)
plt.ylim(-3500, 3500)
plt.title('Electrode ID 5 Media Post-KCl Dosing')
plt.legend() 

# all plots
plt.subplot(236)
plt.plot(times_crcPre_seg1, crcpre_seg1, alpha=0.7, label='CRC Pre-Dosing', color='firebrick')
plt.plot(times_crcCtrl_seg1_aligned, crcCtrl_seg1_aligned, alpha=0.7, label='CRC Vehicle Control (PBS)', color='yellowgreen')
plt.plot(times_crcpost2_seg1, crcpost2_seg1, alpha=0.7, label='Potential Spike', color='blue')
plt.plot(times_mediaPre_seg1, mediaPre_seg1, alpha=0.7, label='Media Pre-KCl', color='pink')
plt.plot(times_mediaPost_seg1, mediaPost_seg1, alpha=0.7, label='Media Post-KCl', color='deeppink')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (µV)')
plt.title('All Segments')
plt.xlim(22.7, 23.5)
plt.ylim(-3500, 3500)
plt.legend()

# %% [markdown]
# Time Calculations

# %%
#define the segments from graphs above
t0_1 = 36.1  # seconds
t1_1 = 36.9

t0_2 = 22.7
t1_2 = 23.5
idx_t0_1 = np.argmin(np.abs(times_crcpost2_seg1 - t0_1))
idx_t1_1 = np.argmin(np.abs(times_crcpost2_seg1 - t1_1)) 
idx_t0_2 = np.argmin(np.abs(times_crcpost2_seg1 - t0_2))
idx_t1_2 = np.argmin(np.abs(times_crcpost2_seg1 - t1_2))

print(f"idx_t0 = {idx_t0_1}")
print(f"idx_t1 = {idx_t1_1}")
print(f"idx_t0_2 = {idx_t0_2}")
print(f"idx_t1_2 = {idx_t1_2}")

# %%
signal_spike1 = crcpost1_seg1[idx_t0_1:idx_t1_1]  # adjust these values based on visual inspection
signal_spike2 = crcpost2_seg1[idx_t0_2:idx_t1_2]  # adjust these values based on visual inspection
# time semegments
time_spike1 = times_crcpost1_seg1[idx_t0_1:idx_t1_1]
time_spike2 = times_crcpost2_seg1[idx_t0_2:idx_t1_2]

# %%
def analyze_spike(signal_spike, time_spike):
    # baseline = mean of first 10%
    n_base = int(0.1 * len(signal_spike))
    V_rest = np.mean(signal_spike[:n_base])

    # depolarization: find minimum
    idx_min = np.argmin(signal_spike)
    V_min = signal_spike[idx_min]
    t_min = time_spike[idx_min]

    # find peak after minimum
    idx_peak = idx_min + np.argmax(signal_spike[idx_min:])
    V_max = signal_spike[idx_peak]
    t_max = time_spike[idx_peak]

    # depolarization time: baseline → min → peak
    idx_rest_before = np.where(signal_spike[:idx_min] > V_rest)[0]
    t_rest = time_spike[idx_rest_before[-1]] if len(idx_rest_before) > 0 else time_spike[0]
    t_depol = t_max - t_rest
    dV_depol = V_max - V_rest
    slope_depol = dV_depol / t_depol

    # repolarization time: peak → baseline
    # repolarization time: peak → baseline
    idx_rest_after_candidates = np.where(signal_spike[idx_peak:] < V_rest)[0]
    if len(idx_rest_after_candidates) > 0:
        idx_rest_after = idx_peak + idx_rest_after_candidates[0]
        t_rest_after = time_spike[idx_rest_after]
        t_repol = t_rest_after - t_max
        V_rest_after = signal_spike[idx_rest_after]
    else:
        t_repol = 0
        t_rest_after = t_max
        V_rest_after = V_rest  # fallback

# delta V for repolarization: from peak down to baseline
    dV_repol = V_max - V_rest_after
    slope_repol = -dV_repol / t_repol if t_repol != 0 else np.nan  # negative slope to show downward

    # hyperpolarization time after repolarization
    post_repol_idx = np.where(time_spike > time_spike[idx_rest_after_candidates[0]] if len(idx_rest_after_candidates) > 0 else t_max)[0]
    hyper_idx = post_repol_idx[signal_spike[post_repol_idx] < V_rest] if len(post_repol_idx) > 0 else []
    t_hyper = (time_spike[hyper_idx[-1]] - time_spike[hyper_idx[0]]) if len(hyper_idx) > 0 else 0

    # outputs: same keys as original function
    return {
        "t_depol": t_depol,
        "t_repol": t_repol,
        "t_hyper": t_hyper,
        "V_depol_abs": V_min,
        "V_repol_abs": V_max,
        "dV_depol": dV_depol,
        "dV_repol": dV_repol,
        "slope_depol": slope_depol,
        "slope_repol": slope_repol,
        "t_rest": t_rest,          
        "t_peak": t_max,          
        "t_rest_after": t_rest_after
    }

# %%
spike1_metrics = analyze_spike(signal_spike1, time_spike1)
spike2_metrics = analyze_spike(signal_spike2, time_spike2)

# %%
# times bar graph

#convert to ms so depol time shows
labels = ['Depolarization', 'Repolarization', 'Hyperpolarization']
#vals1 = [spike1_metrics['t_depol']* 1e3, spike1_metrics['t_repol']* 1e3, spike1_metrics['t_hyper']* 1e3]
#vals2 = [spike2_metrics['t_depol']* 1e3, spike2_metrics['t_repol']* 1e3, spike2_metrics['t_hyper']* 1e3]
vals1 = [spike1_metrics['t_depol'], spike1_metrics['t_repol'], spike1_metrics['t_hyper']]
vals2 = [spike2_metrics['t_depol'], spike2_metrics['t_repol'], spike2_metrics['t_hyper']]

x = np.arange(len(labels))
w = 0.25

plt.figure(figsize=(6,5))
plt.bar(x - w/2, vals1, w, label='Dose 1', alpha = 0.7, color = 'orange')
plt.bar(x + w/2, vals2, w, label='Dose 2', alpha = 0.7, color = 'blue')
plt.xticks(x, labels)
plt.ylabel('Time (s)')
plt.title('Spike Timing Metrics')
plt.legend()
plt.grid(axis='y', alpha=0.3)

# %%
print(spike1_metrics['t_depol'])

print(spike1_metrics['t_hyper'])

# %%
#absolute potentials

labels = ['Depolarization', 'Repolarization']
#x = np.arange(len(labels))   # 0, 1
x=np.array([0.2, 0.8])
w = 0.13

vals1 = [spike1_metrics['V_depol_abs'], spike1_metrics['V_repol_abs']]
vals2 = [spike2_metrics['V_depol_abs'], spike2_metrics['V_repol_abs']]

plt.figure(figsize=(6,5))
plt.bar(x[:2] - w/2, vals1, w, label='Dose 1', alpha = 0.7, color = 'orange')
plt.bar(x[:2] + w/2, vals2, w, label='Dose 2', alpha = 0.7, color = 'blue')
plt.xticks(x[:2], labels)
plt.ylabel('Amplitude (µV)')
plt.title('Absolute Potentials')
plt.xlim(-0.1, 1.1)
plt.legend()

plt.grid(axis='y', alpha=0.3)

# %%
#delta v
labels = ['Depolarization', 'Repolarization']
x=np.array([0.2, 0.8])
w = 0.13

vals1_deltav = [spike1_metrics['dV_depol'], spike1_metrics['dV_repol']]
vals2_deltav = [spike2_metrics['dV_depol'], spike2_metrics['dV_repol']]

plt.figure(figsize=(6,5))
bars1 = plt.bar(x[:2] - w/2, vals1_deltav, w, label='Dose 1', alpha = 0.7, color = 'orange')
bars2 = plt.bar(x[:2] + w/2, vals2_deltav, w, label='Dose 2', alpha = 0.7, color = 'blue')
plt.xticks(x[:2], labels)
plt.ylabel('ΔV (µV)')
plt.title('Change in Potential')
plt.xlim(-0.1, 1.1)
plt.ylim(0, 2000)
plt.legend()
plt.grid(axis = 'y', alpha=0.3)

# Add number labels on top of each bar
for bar in bars1:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.02*max(vals1_deltav+vals2_deltav), f"{yval:.1f}", 
             ha='center', va='bottom', fontsize=10)

for bar in bars2:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.02*max(vals1_deltav+vals2_deltav), f"{yval:.1f}", 
             ha='center', va='bottom', fontsize=10)

# %%
print(vals1_deltav)
print(vals2_deltav)

# %%
#slopes
labels = ['Depolarization', 'Repolarization']
x=np.array([0.2, 0.8])
w = 0.13

vals1 = [spike1_metrics['slope_depol'], spike1_metrics['slope_repol']]
vals2 = [spike2_metrics['slope_depol'], spike2_metrics['slope_repol']]

plt.figure(figsize=(6,5))
plt.bar(x[:2] - w/2, vals1, w, label='Dose 1', alpha = 0.7, color = 'orange')
plt.bar(x[:2] + w/2, vals2, w, label='Dose 2', alpha = 0.7, color = 'blue')
plt.xticks(x[:2], labels)
plt.ylabel('Slope (µV/s)')
plt.title('Spike Slopes')
plt.xlim(-0.1, 1.1)
plt.legend()
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()

# %%
print(x)

# %%
def plot_spike_with_events(signal_spike, time_spike, metrics, Dose):
    """
    signal_spike: array of voltage values
    time_spike: array of corresponding times
    metrics: dict returned by analyze_spike()
    Dose: string, dose label for title
    """
    plt.figure(figsize=(8,4))
    plt.plot(time_spike, signal_spike, color='black', label='Signal')

    # Depolarization start (baseline crossing before min)
    plt.axvline(metrics['t_rest'], color='orange', linestyle='--', label='Depol start')

    # Depolarization end / Repolarization start (peak)
    idx_peak = np.argwhere(signal_spike == metrics['V_repol_abs'])[0][0]
    t_peak = time_spike[idx_peak]
    plt.axvline(t_peak, color='blue', linestyle='--', label='Depol end / Repol start')

    # Repolarization end / next depolarization start (baseline after peak)
    idx_rest_after_candidates = np.where(signal_spike[idx_peak:] < np.mean(signal_spike[:int(0.1*len(signal_spike))]))[0]
    if len(idx_rest_after_candidates) > 0:
        idx_rest_after = idx_peak + idx_rest_after_candidates[0]
        t_rest_after = time_spike[idx_rest_after]
        plt.axvline(t_rest_after, color='green', linestyle='--', label='Repol end')
    else:
        t_rest_after = t_peak

    # Hyperpolarization end (end of below-baseline period after repolarization)
    if metrics['t_hyper'] > 0:
        t_hyper_end = t_rest_after + metrics['t_hyper']
        plt.axvline(t_hyper_end, color='purple', linestyle='--', label='Hyperpol end')

    plt.xlabel('Time (ms)')
    plt.ylabel('Voltage (µV)')
    plt.title(f'Spike with Depolarization/Repolarization Events for {Dose}')
    plt.ylim(-3000, 3000)
    plt.legend()
    plt.grid(alpha=0.3)
    plt.show()

# %%
plot_spike_with_events(signal_spike1, time_spike1, spike1_metrics, "Dose 1")

# %%
plot_spike_with_events(signal_spike2, time_spike2, spike2_metrics, "Dose 2")
