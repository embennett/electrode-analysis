# %%
#imports
import os
from pathlib import Path 
import allego_file_reader as afr
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt

# %%
# this is needed to read in the files for CaCl
target_dir = "/Users/ebennett/Library/CloudStorage/Dropbox-EMI/Evelyn Bennett/project_electrodes/electrode_data/organox-electrode-analysis-main/Data/20260115_CRC_KCl" # data directory
p = Path(target_dir).expanduser()

# %%
all_xdat_datasource_names = [Path(elem.stem).stem for elem in list(p.glob('**/*xdat.json'))]
for idx, name in enumerate(all_xdat_datasource_names):
    print(f"{idx}: {name}")

# can use index instead of oulling file name

# %%
# read in pre-treatment media reading
base_name = all_xdat_datasource_names[1] # first base name
#base_name = 'file'
print("Will work with file %s" % base_name)
file_path_mediaPre = str(Path(target_dir, base_name))
time_range = afr.get_allego_xdat_time_range(file_path_mediaPre)
time_range

# %%
time_start = 0
time_end = 180
pri_signals_mediaPre, timestamps_mediaPre, time_samples_mediaPre = afr.read_allego_xdat_pri_signals(file_path_mediaPre, 
                                                                         time_start, time_end)

# %%
# read in pre-treatment crc reading
base_name = all_xdat_datasource_names[0] # first base name
print("Will work with file %s" % base_name)
file_path_crcPre = str(Path(target_dir, base_name))
time_range = afr.get_allego_xdat_time_range(file_path_crcPre)
time_range

# %%
time_start = 0
time_end = 180
pri_signals_crcPre, timestamps_crcPre, time_samples_crcPre = afr.read_allego_xdat_pri_signals(file_path_crcPre, 
                                                                         time_start, time_end)

print(pri_signals_crcPre.shape)

# %%
# read in post control treatment (PBS) crc reading
base_name = all_xdat_datasource_names[3] # first base name
print("Will work with file %s" % base_name)
file_path_crcCtrl = str(Path(target_dir, base_name))
time_range = afr.get_allego_xdat_time_range(file_path_crcCtrl)
time_range

# %%
time_start = 0
time_end = 180
pri_signals_crcCtrl, timestamps_crcCtrl, time_samples_crcCtrl = afr.read_allego_xdat_pri_signals(file_path_crcCtrl, 
                                                                         time_start, time_end)

# %%
# read in post-treatment 1 crc reading
base_name = all_xdat_datasource_names[2] # first base name
print("Will work with file %s" % base_name)
file_path_crcPost1 = str(Path(target_dir, base_name))
time_range = afr.get_allego_xdat_time_range(file_path_crcPost1)
time_range

# %%
time_start = 0
time_end = 180
pri_signals_crcPost1, timestamps_crcPost1, time_samples_crcPost1 = afr.read_allego_xdat_pri_signals(file_path_crcPost1, 
                                                                         time_start, time_end)

# %%
# read in post-treatment 2 crc reading
base_name = all_xdat_datasource_names[5] # first base name
print("Will work with file %s" % base_name)
file_path_crcPost2 = str(Path(target_dir, base_name))
time_range = afr.get_allego_xdat_time_range(file_path_crcPost2)
time_range

# %%
time_start = 0
time_end = 180
pri_signals_crcPost2, timestamps_crcPost2, time_samples_crcPost2 = afr.read_allego_xdat_pri_signals(file_path_crcPost2, 
                                                                         time_start, time_end)

# %%
# read in post-treatment media reading
base_name = all_xdat_datasource_names[4] # first base name
print("Will work with file %s" % base_name)
file_path_mediaPost = str(Path(target_dir, base_name))
time_range = afr.get_allego_xdat_time_range(file_path_mediaPost)
time_range

# %%
time_start = 0
time_end = 180
pri_signals_mediaPost, timestamps_mediaPost, time_samples_mediaPost = afr.read_allego_xdat_pri_signals(file_path_mediaPost, 
                                                                         time_start, time_end)

# %%
id=5

start = int(0)
end   = int(5e6) # fix to be the full index range

times_mediaPre = time_samples_mediaPre[start:end]
times_mediaPost = time_samples_mediaPost[start:end]
times_crcCtrl = time_samples_crcCtrl[start:end]
times_crcPre = time_samples_crcPre[start:end]
times_crcpost1 = time_samples_crcPost1[start:end]
times_crcpost2 = time_samples_crcPost2[start:end]

mediaPre_seg = pri_signals_mediaPre[id][start:end]
mediaPost_seg  = pri_signals_mediaPost[id][start:end]
crcCtrl_seg = pri_signals_crcCtrl[id][start:end]
crcpre_seg = pri_signals_crcPre[id][start:end]
crcpost1_seg = pri_signals_crcPost1[id][start:end]
crcpost2_seg = pri_signals_crcPost2[id][start:end]

# %%
plt.plot(crcpost1_seg, alpha=0.7, label='CRC Post-KCl Treatment 1', color='orange')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (µV)')
#plt.xlim(0, 38)
#plt.ylim(-6000, 6000)
plt.legend()

# %%
plt.plot(times_crcpost1, crcpost1_seg, alpha=0.7, label='CRC Post-KCl Treatment 1', color='orange')
#plt.plot(time_seg, signal_cleaned.real[start:end], label='iFFT Cleaned Signal', color='purple')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (µV)')
plt.xlim(0, 38)
#plt.ylim(-6000, 6000)
plt.legend()

# %%
plt.plot(times_crcpost2, crcpost2_seg, alpha=0.7, label='CRC Post-KCl Treatment 2', color='blue')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (µV)')
plt.xlim(0, 30)
plt.ylim(-6000, 6000)
plt.legend()

# %%
plt.figure(figsize=(16, 25))
plt.subplot(321)
plt.plot(times_crcpost1, crcpost1_seg, alpha=0.7, label='CRC Post-KCl Treatment 1', color='orange')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (µV)')
plt.xlim(0, 40)
plt.ylim(-8000, 6000)
plt.title('CRC Post-KCl Treatment 1')
plt.legend()

plt.subplot(322)
plt.plot(times_crcpost2, crcpost2_seg, alpha=0.7, label='CRC Post-KCl Treatment 2', color='blue')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (µV)')
plt.xlim(0, 40)
plt.ylim(-8000, 6000)
plt.title('CRC Post-KCl Treatment 2')
plt.legend()

plt.subplot(3, 2, (3, 4))
plt.plot(times_crcpost1, crcpost1_seg, alpha=0.7, label='CRC Post-KCl Treatment 1', color='orange')
plt.plot(times_crcpost2, crcpost2_seg, alpha=0.7, label='CRC Post-KCl Treatment 2', color='blue')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (µV)')
plt.xlim(0, 40)
plt.ylim(-8000, 6000)
plt.title('CRC Post-KCl Treatments 1 and 2 Comparison')
plt.legend()


crcpost1_seg_adjust = pri_signals_crcPost1[id][int(0.31e6):end]
crcpost1_seg_adjust_time = time_samples_crcPost1[start:int(4.69e6)]

plt.subplot(3, 2, (5, 6))
plt.plot(crcpost1_seg_adjust_time, crcpost1_seg_adjust, alpha=0.7, label='CRC Post-KCl Treatment 1', color='orange')
plt.plot(times_crcpost2, crcpost2_seg, alpha=0.7, label='CRC Post-KCl Treatment 2', color='blue')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (µV)')
plt.xlim(0, 40)
plt.ylim(-8000, 6000)
plt.title('CRC Post-KCl Treatments 1 and 2 Comparison - Aligned')
plt.legend()

# %%
plt.figure(figsize=(8, 12))
plt.subplot(211)
plt.plot(times_crcpost1, crcpost1_seg, alpha=0.7, label='Potential Spike', color='orange')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (µV)')
plt.xlim(36, 37)
plt.ylim(-3000, 3000)
plt.title('CRC Post-KCl Treatment 1 - Potential Spike Segment')
plt.legend()


plt.subplot(212)
plt.plot(times_crcpost1, crcpost1_seg, alpha=0.7, label='Noise', color='orange')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (µV)')
plt.xlim(18, 19)
plt.ylim(-3000, 3000)
plt.title('CRC Post-KCl Treatment 1 - Noise Segment')
plt.legend()

# %%
#figure saving directory
main_dir = os.getcwd()                   # current working directory
figures_dir = os.path.join(main_dir, "Figures")
os.makedirs(figures_dir, exist_ok=True) # create folder if it doesn't exist

# %%
print(times_mediaPre)

# %%
# media conparison plot
# just media comparison
plt.figure(figsize=(10,10))

plt.subplot(2,2,1)
plt.plot( times_mediaPre, mediaPre_seg, label='Media Pre', color='pink')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (µV)')
plt.title('Media Pre-Treatment')
plt.legend()
plt.ylim(-40, 40)

plt.subplot(2,2,2)
plt.plot(times_mediaPost, mediaPost_seg, alpha=0.7, label='Media Post', color='deeppink')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (µV)')
plt.title('Media Post-Treatment')
plt.legend()
plt.ylim(-40, 40)

plt.subplot(2,2, (3,4))
plt.plot(times_mediaPre, mediaPre_seg, label='Media Pre', color='pink')
plt.plot(times_mediaPost, mediaPost_seg, alpha=0.7, label='Media Post', color='deeppink')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (µV)')
plt.title('Media Post vs Pre Treatment')
plt.legend()
plt.ylim(-40, 40)

save_path = os.path.join(figures_dir, f"media_comparison_channel{id}.png")
plt.savefig(save_path, dpi=300)

# %%
#the three crc treatments together
plt.figure(figsize=(25,20))
plt.subplot(322)
plt.plot(times_crcPre, crcpre_seg, alpha=0.7, label='CRC Pre-Glucose', color='blue')
plt.xlabel('Sample Index')
plt.ylabel('Amplitude (µV)')
plt.title('CRC Pre-Glucose Treatment')
plt.legend()
plt.ylim(-3000, 3000)

plt.subplot(323)
plt.plot(times_crcpost1, crcpost1_seg, alpha=0.7, label='CRC Post-CaCl2 Treatment 1', color='orange')
plt.xlabel('Sample Index')
plt.ylabel('Amplitude (µV)')
plt.title('CRC Post-CaCl2 Treatment 1')
plt.legend()
plt.ylim(-3000, 3000)

plt.subplot(324)
plt.plot(times_crcpost2, crcpost2_seg, alpha=0.7, label='CRC Post-CaCl2 Treatment 2', color='orangered')
plt.xlabel('Sample Index')
plt.ylabel('Amplitude (µV)')
plt.title('CRC Post-CaCl2 Treatment 2')
plt.legend()
plt.ylim(-3000, 3000)

plt.subplot(321)
plt.plot(times_crcCtrl, crcCtrl_seg, alpha=0.7, label='CRC Control (PBS) Treatment', color='yellowgreen')
plt.xlabel('Sample Index')
plt.ylabel('Amplitude (µV)')
plt.title('CRC Media Control Treatment')
plt.legend()
plt.ylim(-3000, 3000)

plt.subplot(3,2,(5,6))
plt.plot(times_crcCtrl, crcCtrl_seg, alpha=0.7, label='CRC Control (PBS) Treatment', color='yellowgreen')
plt.plot(times_crcPre, crcpre_seg, alpha=0.7, label='CRC Pre-Glucose', color='blue')
plt.plot(times_crcpost1, crcpost1_seg, alpha=0.7, label='CRC Post-Glucose', color='orange')
plt.plot(times_crcpost2, crcpost2_seg, alpha=0.7, label='CRC Post-Glucose', color='orangered')
plt.xlabel('Sample Index')
plt.ylabel('Amplitude (µV)')
plt.title('All CRC Treatments')
plt.legend()
plt.ylim(-3000, 3000)

save_path = os.path.join(figures_dir, f"crc_glu_comparison_channel{id}.png")
plt.savefig(save_path, dpi=300)

# %% [markdown]
# iFFt Plots

# %%
# try cleaning one signal with iFFT
from scipy.fft import rfft, irfft, rfftfreq
fs = 30000.0

dt = 1.0 / fs
segment = crcpost1_seg
N = len(segment)
f = rfftfreq(N, dt)

F = rfft(segment)


plt.figure(figsize=(10,8))
plt.vlines(f[:N//2], 0,  2.0/N * np.abs(F[0:N//2]), label='Post-CaCl2 Treatment 1', color='blue')
plt.xlim(-3, 1500) # limit x-axis to 1500 Hz
plt.axvline(x=400, linestyle='--', color='black')
#plt.ylim(0,5)
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude (µV)')
plt.legend()

# %%
#plot iFFT cleaned signal
from scipy.fft import ifft
F_cleaned = F.copy()
time_seg   = times_crcpost1[start:end]
original_seg = crcpost1_seg[start:end]
# Zero out frequencies above 400 Hz
F_cleaned[np.abs(f) > 400] = 0         
signal_cleaned = irfft(F_cleaned)
plt.figure(figsize=(35,12))
plt.plot(time_seg, signal_cleaned.real[start:end], label='iFFT Cleaned Signal', color='purple')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (µV)')
plt.title('iFFT Cleaned Signal (Low Pass Filter at 500 Hz)')
plt.legend()

# %%
plt.figure(figsize=(35,12))
plt.plot(times_crcpost1, crcpost1_seg, alpha=0.7, label='CRC Post-KCl', color='orange')
plt.plot(time_seg, signal_cleaned.real[start:end], label='iFFT Cleaned Signal', color='purple')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (µV)')
plt.xlim(15, 40)
plt.ylim(-3000, 2200)
plt.title('iFFT Cleaned Signal (Low Pass Filter at 500 Hz)')
plt.legend()
